# %%
import pandas as pd

# %%
df=pd.read_csv("/run/media/magus/data/wd/omdena/eco_smart_ai_dhaka/src/data/air quality data/A Real-time Dataset of Air Pollution Monitoring Generated Using IoT/my_ap_dataset.csv")

# %%
df.tail()
# Out:
#                     date  Station code                     Address   Latitude  \
# 155400  12/31/2022 19:00           103  Tongi, Gazipur, Bangladesh  23.894144
# 155401  12/31/2022 20:00           103  Tongi, Gazipur, Bangladesh  23.894144
# 155402  12/31/2022 21:00           103  Tongi, Gazipur, Bangladesh  23.894144
# 155403  12/31/2022 22:00           103  Tongi, Gazipur, Bangladesh  23.894144
# 155404  12/31/2022 23:00           103  Tongi, Gazipur, Bangladesh  23.894144
#
#         Longitude   SO2    NO2   CO      O3  PM2.5  PM10
# 155400  90.404219  0.02  0.030  3.5  0.1100     59    99
# 155401  90.404219  0.02  0.030  3.5  0.1000     61   101
# 155402  90.404219  0.02  0.028  3.5  0.1000     62   100
# 155403  90.404219  0.02  0.042  3.6  0.0525     65   106
# 155404  90.404219  0.02  0.037  3.5  0.0400     64   104

# %%
locations = df['Address'].unique()

print(locations)
# Out:
# ['Kuril Bishow Road, Dhaka, Bangladesh' 'Uttara, Dhaka, Bangladesh'
#  'Tongi, Gazipur, Bangladesh']

# %%
locations = df['Latitude'].unique()

print(locations)
# Out:
# [23.820612 23.851008 23.894144]

# %%
locations = df['Longitude'].unique()

print(locations)
# Out:
# [90.421011 90.371365 90.404219]

# %%
df=pd.read_csv("/run/media/magus/data/wd/omdena/eco_smart_ai_dhaka/src/data/air-pollution-data/my_ap_dataset.csv")

# %%
df
# Out:
#                     date  Station code                               Address  \
# 0          1/1/2017 0:00           101  Kuril Bishow Road, Dhaka, Bangladesh
# 1          1/1/2017 1:00           101  Kuril Bishow Road, Dhaka, Bangladesh
# 2          1/1/2017 2:00           101  Kuril Bishow Road, Dhaka, Bangladesh
# 3          1/1/2017 3:00           101  Kuril Bishow Road, Dhaka, Bangladesh
# 4          1/1/2017 4:00           101  Kuril Bishow Road, Dhaka, Bangladesh
# ...                  ...           ...                                   ...
# 155400  12/31/2022 19:00           103            Tongi, Gazipur, Bangladesh
# 155401  12/31/2022 20:00           103            Tongi, Gazipur, Bangladesh
# 155402  12/31/2022 21:00           103            Tongi, Gazipur, Bangladesh
# 155403  12/31/2022 22:00           103            Tongi, Gazipur, Bangladesh
# 155404  12/31/2022 23:00           103            Tongi, Gazipur, Bangladesh
#
# ...
